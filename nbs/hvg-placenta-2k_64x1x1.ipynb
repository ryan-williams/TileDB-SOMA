# %%
meas = "RNA"
layer = "raw"
census = "2024-07-01"
tissue = "tongue"
var_filter = None
dask_chunk_size = 0  # Non-Dask mode, by default
n_workers = None
threads_per_worker = 1
tdb_workers = 4
dashboard_port = 8787

# %%
# Parameters
tissue = "placenta"
dask_chunk_size = 2000
n_workers = 64
threads_per_worker = 1
tdb_workers = 1
dashboard_port = 8786

# %%
from concurrent.futures import ThreadPoolExecutor
from os import cpu_count
from typing import Literal
import anndata as ad
import scanpy as sc
from somacore import AxisQuery
from tiledbsoma import Experiment, SOMATileDBContext

DEFAULT_CONFIG = {
    "vfs.s3.no_sign_request": "true",
    "vfs.s3.region": "us-west-2"
}
CENSUS_S3 = "s3://cellxgene-census-public-us-west-2/cell-census"

species = "homo_sapiens"
soma_uri = f"{CENSUS_S3}/{census}/soma"
exp_uri = f"{soma_uri}/census_data/{species}"

exp = Experiment.open(
    exp_uri,
    context=SOMATileDBContext(
        tiledb_config=DEFAULT_CONFIG,
        threadpool=ThreadPoolExecutor(max_workers=tdb_workers),
    ),
)
exp
# Out:
# <Experiment 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens' (open for 'r') (2 items)
#     'ms': 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens/ms' (unopened)
#     'obs': 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens/obs' (unopened)>

# %%
# %%time
obs_filter = f'tissue_general == "{tissue}"' if tissue else None
query = exp.axis_query(
    measurement_name=meas,
    obs_query=AxisQuery(value_filter=obs_filter) if obs_filter else None,
    var_query=AxisQuery(value_filter=var_filter) if var_filter else None,
)
# Out:
# CPU times: user 9.47 ms, sys: 8.97 ms, total: 18.4 ms
# Wall time: 202 ms

# %%
# %%time
query.n_obs
# Out:
# CPU times: user 603 ms, sys: 1.31 s, total: 1.91 s
# Wall time: 431 ms
# 638786

# %%
from dask.distributed import Client, LocalCluster
if dask_chunk_size:
    if n_workers is None:
        n_workers = cpu_count() // tdb_workers // threads_per_worker
    cluster = LocalCluster(
        n_workers=n_workers,
        threads_per_worker=threads_per_worker,
        dashboard_address=f":{dashboard_port}",
    )
    print(f"{n_workers=}, {threads_per_worker=}, {tdb_workers=}")
    client = Client(cluster)
else:
    dask_chunk_size = None
    client = None
client
# Out:
# n_workers=64, threads_per_worker=1, tdb_workers=1
# <Client: 'tcp://127.0.0.1:43229' processes=64 threads=64, memory=246.55 GiB>

# %% [markdown]
# ## HVG

# %%
# %%time
add = query.to_anndata(layer, dask_chunk_size=dask_chunk_size)
add
# Out:
# CPU times: user 2.15 s, sys: 2.34 s, total: 4.49 s
# Wall time: 1.94 s
# AnnData object with n_obs × n_vars = 638786 × 60530
#     obs: 'soma_joinid', 'dataset_id', 'assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'observation_joinid', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'suspension_type', 'tissue', 'tissue_ontology_term_id', 'tissue_type', 'tissue_general', 'tissue_general_ontology_term_id', 'raw_sum', 'nnz', 'raw_mean_nnz', 'raw_variance_nnz', 'n_measured_vars'
#     var: 'soma_joinid', 'feature_id', 'feature_name', 'feature_length', 'nnz', 'n_measured_obs'

# %%
# %%time
sc.pp.normalize_total(add)
# Out:
# CPU times: user 100 ms, sys: 30.3 ms, total: 130 ms
# Wall time: 125 ms

# %%
# %%time
sc.pp.log1p(add)
# Out:
# CPU times: user 3.92 ms, sys: 984 μs, total: 4.91 ms
# Wall time: 4.73 ms

# %%
# %%time
hvg = sc.pp.highly_variable_genes(add, inplace=False, subset=True)
hvg
# Out:
# 2025-01-29 21:08:09,731 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.56 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:13,148 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.70 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:14,577 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.65 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:14,786 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.55 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:15,008 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:15,409 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.82 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:15,993 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.46 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:16,500 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.71 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:17,548 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.63 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:17,627 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.70 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:18,842 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.70 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:18,877 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.53 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:18,886 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.62 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:18,908 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.71 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:19,136 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.70 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:19,177 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.61 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:19,486 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.63 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:19,545 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.52 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:19,722 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.47 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:20,109 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.73 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:20,199 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.65 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:20,231 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.46 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:20,233 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.68 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:20,430 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.66 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:20,511 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.63 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:20,589 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.61 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:20,961 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.64 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:22,363 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.66 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:22,452 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.55 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:22,608 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.66 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:22,610 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.59 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:23,221 - distributed.worker.memory - WARNING - gc.collect() took 2.806s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:08:23,222 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.12 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:23,320 - distributed.worker.memory - WARNING - Worker is at 29% memory usage. Resuming worker. Process memory: 1.14 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:23,512 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.45 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:24,588 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.55 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:25,126 - distributed.worker.memory - WARNING - gc.collect() took 2.987s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:08:25,127 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.11 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:25,153 - distributed.worker.memory - WARNING - Worker is at 29% memory usage. Resuming worker. Process memory: 1.13 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:26,155 - distributed.worker.memory - WARNING - gc.collect() took 2.384s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:08:26,156 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.12 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:26,237 - distributed.worker.memory - WARNING - Worker is at 32% memory usage. Resuming worker. Process memory: 1.24 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:27,669 - distributed.worker.memory - WARNING - gc.collect() took 2.819s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:08:27,671 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.10 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:27,761 - distributed.worker.memory - WARNING - Worker is at 30% memory usage. Resuming worker. Process memory: 1.18 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:28,742 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.49 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:31,748 - distributed.worker.memory - WARNING - gc.collect() took 4.510s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:08:31,749 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.10 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:31,771 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.59 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:31,876 - distributed.worker.memory - WARNING - Worker is at 28% memory usage. Resuming worker. Process memory: 1.11 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:35,154 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.51 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:35,625 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.52 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:35,922 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.63 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:37,564 - distributed.worker.memory - WARNING - gc.collect() took 2.420s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:08:37,566 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.10 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:37,663 - distributed.worker.memory - WARNING - Worker is at 30% memory usage. Resuming worker. Process memory: 1.17 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:37,903 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.57 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:37,905 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.84 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:42,879 - distributed.worker.memory - WARNING - gc.collect() took 1.991s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:08:42,880 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.11 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:08:42,984 - distributed.worker.memory - WARNING - Worker is at 30% memory usage. Resuming worker. Process memory: 1.18 GiB -- Worker memory limit: 3.85 GiB
# CPU times: user 56.5 s, sys: 14.3 s, total: 1min 10s
# Wall time: 1min 20s
#           means  dispersions          mean_bin  dispersions_norm  \
# 14     0.092254     2.359177  (-0.00561, 0.28]          0.865045
# 15     0.018185     2.020049  (-0.00561, 0.28]          0.553303
# 24     0.428312     4.409582     (0.28, 0.561]          4.928617
# 26     0.028136     2.201727  (-0.00561, 0.28]          0.720310
# 33     0.013141     2.132764  (-0.00561, 0.28]          0.656916
# ...         ...          ...               ...               ...
# 57029  0.016431     2.532290  (-0.00561, 0.28]          1.024178
# 57873  0.032180     2.455130  (-0.00561, 0.28]          0.953249
# 59217  0.063744     2.072049  (-0.00561, 0.28]          0.601104
# 59353  0.013538     2.208245  (-0.00561, 0.28]          0.726302
# 59611  0.029507     2.006180  (-0.00561, 0.28]          0.540555
#
#        highly_variable
# 14                True
# 15                True
# 24                True
# 26                True
# 33                True
# ...                ...
# 57029             True
# 57873             True
# 59217             True
# 59353             True
# 59611             True
#
# [2919 rows x 5 columns]

# %% [markdown]
# ---
# Census `tissue_general` counts, for reference:
# ```python
# exp_obs = exp.obs.read().concat().to_pandas()
# exp_obs.tissue_general.value_counts()
# ```
# ```
# tissue_general
# brain                       26281059
# blood                       10835244
# lung                         6231233
# breast                       5555979
# eye                          4190842
# heart                        3629952
# kidney                       2083054
# liver                        1815408
# small intestine              1237182
# skin of body                 1045024
# endocrine gland               979667
# respiratory system            944355
# bone marrow                   813373
# spleen                        751041
# lymph node                    717899
# colon                         714413
# placenta                      638786
# reproductive system           570488
# adrenal gland                 560114
# nose                          470445
# adipose tissue                468603
# stomach                       446348
# prostate gland                348664
# fallopian tube                250178
# pancreas                      250161
# esophagus                     215951
# digestive system              211912
# musculature                   189452
# large intestine               180996
# pleural fluid                 179134
# yolk sac                      169725
# embryo                        165937
# uterus                        148198
# mucosa                        131978
# spinal cord                   117463
# exocrine gland                115722
# intestine                     104490
# immune system                  89046
# bladder organ                  82797
# vasculature                    63667
# ovary                          53751
# lamina propria                 45230
# tongue                         45060
# central nervous system         31780
# esophagogastric junction       29105
# axilla                         19792
# pleura                         19695
# skeletal system                14680
# saliva                         14502
# omentum                        14003
# testis                         13211
# tendon of semitendinosus       10533
# gallbladder                     9769
# scalp                           3029
# ureter                          2390
# Name: count, dtype: int64
# ```
