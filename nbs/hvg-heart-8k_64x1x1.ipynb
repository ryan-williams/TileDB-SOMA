# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [10]</a>'.</span>

# %%
meas = "RNA"
layer = "raw"
census = "2024-07-01"
tissue = "tongue"
var_filter = None
dask_chunk_size = 0  # Non-Dask mode, by default
n_workers = None
threads_per_worker = 1
tdb_workers = None
dashboard_port = 8787

# %%
# Parameters
tissue = "heart"
dask_chunk_size = 8000
n_workers = 64
threads_per_worker = 1
tdb_workers = 1
dashboard_port = 8786

# %%
from concurrent.futures import ThreadPoolExecutor
from os import cpu_count
from typing import Literal
import anndata as ad
import scanpy as sc
from somacore import AxisQuery
from tiledbsoma import Experiment, SOMATileDBContext

DEFAULT_CONFIG = {
    "vfs.s3.no_sign_request": "true",
    "vfs.s3.region": "us-west-2"
}
CENSUS_S3 = "s3://cellxgene-census-public-us-west-2/cell-census"

species = "homo_sapiens"
soma_uri = f"{CENSUS_S3}/{census}/soma"
exp_uri = f"{soma_uri}/census_data/{species}"

if not tdb_workers:
    tdb_workers = cpu_count()

exp = Experiment.open(
    exp_uri,
    context=SOMATileDBContext(
        tiledb_config=DEFAULT_CONFIG,
        threadpool=ThreadPoolExecutor(max_workers=tdb_workers),
    ),
)
exp
# Out:
# <Experiment 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens' (open for 'r') (2 items)
#     'ms': 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens/ms' (unopened)
#     'obs': 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens/obs' (unopened)>

# %%
# %%time
obs_filter = f'tissue_general == "{tissue}"' if tissue else None
query = exp.axis_query(
    measurement_name=meas,
    obs_query=AxisQuery(value_filter=obs_filter) if obs_filter else None,
    var_query=AxisQuery(value_filter=var_filter) if var_filter else None,
)
# Out:
# CPU times: user 8.75 ms, sys: 7.75 ms, total: 16.5 ms
# Wall time: 170 ms

# %%
# %%time
query.n_obs
# Out:
# CPU times: user 634 ms, sys: 1.48 s, total: 2.12 s
# Wall time: 458 ms
# 3629952

# %%
from dask.distributed import Client, LocalCluster
if dask_chunk_size:
    if n_workers is None:
        n_workers = cpu_count() // tdb_workers // threads_per_worker
    cluster = LocalCluster(
        n_workers=n_workers,
        threads_per_worker=threads_per_worker,
        dashboard_address=f":{dashboard_port}",
    )
    print(f"{n_workers=}, {threads_per_worker=}, {tdb_workers=}")
    client = Client(cluster)
else:
    dask_chunk_size = None
    client = None
client
# Out:
# n_workers=64, threads_per_worker=1, tdb_workers=1
# <Client: 'tcp://127.0.0.1:37205' processes=64 threads=64, memory=246.55 GiB>

# %% [markdown]
# ## HVG

# %%
# %%time
add = query.to_anndata(layer, dask_chunk_size=dask_chunk_size)
add
# Out:
# CPU times: user 6.65 s, sys: 4.05 s, total: 10.7 s
# Wall time: 5.61 s
# AnnData object with n_obs × n_vars = 3629952 × 60530
#     obs: 'soma_joinid', 'dataset_id', 'assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'observation_joinid', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'suspension_type', 'tissue', 'tissue_ontology_term_id', 'tissue_type', 'tissue_general', 'tissue_general_ontology_term_id', 'raw_sum', 'nnz', 'raw_mean_nnz', 'raw_variance_nnz', 'n_measured_vars'
#     var: 'soma_joinid', 'feature_id', 'feature_name', 'feature_length', 'nnz', 'n_measured_obs'

# %%
# %%time
sc.pp.normalize_total(add)
# Out:
# CPU times: user 423 ms, sys: 113 ms, total: 537 ms
# Wall time: 513 ms

# %%
# %%time
sc.pp.log1p(add)
# Out:
# CPU times: user 2.34 ms, sys: 658 μs, total: 3 ms
# Wall time: 3.02 ms

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
# %%time
hvg = sc.pp.highly_variable_genes(add, inplace=False, subset=True)
hvg
# Out:
# /home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/client.py:3371: UserWarning: Sending large graph of size 17.85 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# 2025-01-29 22:00:08,339 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:09,260 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.70 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:11,344 - distributed.worker.memory - WARNING - gc.collect() took 1.771s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:11,355 - distributed.worker.memory - WARNING - Worker is at 85% memory usage. Pausing worker.  Process memory: 3.29 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:11,453 - distributed.worker.memory - WARNING - Worker is at 59% memory usage. Resuming worker. Process memory: 2.29 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:15,225 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:15,278 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.68 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:16,818 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:16,971 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:18,169 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.68 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:18,677 - distributed.worker.memory - WARNING - gc.collect() took 1.667s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:18,678 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 3.20 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:18,697 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:18,754 - distributed.worker.memory - WARNING - Worker is at 42% memory usage. Resuming worker. Process memory: 1.64 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:18,778 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:19,327 - distributed.worker.memory - WARNING - gc.collect() took 1.484s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:19,327 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:19,400 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:19,431 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:20,012 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.66 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:20,362 - distributed.worker.memory - WARNING - gc.collect() took 1.713s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:20,364 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 3.20 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:20,451 - distributed.worker.memory - WARNING - Worker is at 59% memory usage. Resuming worker. Process memory: 2.28 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:20,676 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.70 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:20,898 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.64 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:21,171 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:21,350 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.65 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:21,463 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.72 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:22,432 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.64 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:22,760 - distributed.worker.memory - WARNING - gc.collect() took 1.331s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:22,761 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:22,813 - distributed.worker.memory - WARNING - Worker is at 42% memory usage. Resuming worker. Process memory: 1.66 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:23,060 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.64 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:23,834 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:23,871 - distributed.worker.memory - WARNING - Worker is at 59% memory usage. Resuming worker. Process memory: 2.29 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:23,978 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.66 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:24,404 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.65 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:24,581 - distributed.worker.memory - WARNING - gc.collect() took 1.818s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:24,583 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.09 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:24,648 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.66 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:24,899 - distributed.worker.memory - WARNING - gc.collect() took 1.969s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:24,900 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 3.24 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:25,044 - distributed.worker.memory - WARNING - Worker is at 48% memory usage. Resuming worker. Process memory: 1.86 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:25,047 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.61 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:25,592 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:25,906 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.77 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:25,985 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.50 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:26,122 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.70 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:26,734 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.64 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:26,980 - distributed.worker.memory - WARNING - gc.collect() took 1.631s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:26,988 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.10 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:27,143 - distributed.worker.memory - WARNING - Worker is at 38% memory usage. Resuming worker. Process memory: 1.50 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:27,381 - distributed.worker.memory - WARNING - gc.collect() took 2.915s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:27,383 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.12 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:27,494 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.57 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:27,632 - distributed.worker.memory - WARNING - gc.collect() took 3.218s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:27,634 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 3.40 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:27,777 - distributed.worker.memory - WARNING - Worker is at 42% memory usage. Resuming worker. Process memory: 1.62 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:27,882 - distributed.worker.memory - WARNING - gc.collect() took 2.635s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:27,888 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:27,954 - distributed.worker.memory - WARNING - Worker is at 44% memory usage. Resuming worker. Process memory: 1.71 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:28,009 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:28,378 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.61 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:28,416 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.66 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:28,535 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.71 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:28,543 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.78 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:28,609 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.64 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:28,753 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.49 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:28,768 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.48 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:29,290 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.48 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:29,428 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.49 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:29,752 - distributed.worker.memory - WARNING - gc.collect() took 3.589s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:29,753 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:29,840 - distributed.worker.memory - WARNING - gc.collect() took 2.981s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:29,845 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:29,846 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:29,923 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:30,119 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.63 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:30,156 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.66 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:30,336 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.63 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:30,388 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.09 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:30,433 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.62 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:30,602 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.48 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:30,774 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.63 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:30,822 - distributed.worker.memory - WARNING - Worker is at 75% memory usage. Resuming worker. Process memory: 2.90 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:30,873 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.62 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:30,935 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.65 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:31,178 - distributed.worker.memory - WARNING - gc.collect() took 3.949s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:31,189 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:31,274 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.67 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:31,979 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.63 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:32,031 - distributed.worker.memory - WARNING - gc.collect() took 2.092s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:32,037 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory:
GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:53,193 - distributed.worker.memory - WARNING - Worker is at 75% memory usage. Resuming worker. Process memory: 2.90 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:53,277 - distributed.worker.memory - WARNING - gc.collect() took 2.567s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:53,279 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.14 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:53,320 - distributed.worker.memory - WARNING - Worker is at 42% memory usage. Resuming worker. Process memory: 1.64 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:54,069 - distributed.worker.memory - WARNING - gc.collect() took 1.844s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 22:00:54,075 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.10 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:54,132 - distributed.worker.memory - WARNING - Worker is at 42% memory usage. Resuming worker. Process memory: 1.65 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:54,422 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.14 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:54,525 - distributed.worker.memory - WARNING - Worker is at 76% memory usage. Resuming worker. Process memory: 2.95 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:55,047 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.15 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:55,161 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:55,459 - distributed.worker.memory - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 3.05 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:00:55,465 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.10 GiB -- Worker memory limit: 3.85 GiB
# ...
# 2025-01-29 22:02:38,792 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.68 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:39,133 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.13 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:39,436 - distributed.worker.memory - WARNING - Worker is at 73% memory usage. Resuming worker. Process memory: 2.84 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:39,476 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.09 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:39,611 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37411
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/utils.py", line 1910, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/comm/tcp.py", line 546, in connect
#     stream = await self.client.connect(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/tornado/tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/worker.py", line 2878, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-01-29 22:02:40,855 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 2.12 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:41,011 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.14 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:41,016 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.11 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:42,594 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:42,743 - distributed.worker.memory - WARNING - Worker is at 68% memory usage. Resuming worker. Process memory: 2.62 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:42,969 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.13 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:43,014 - distributed.worker.memory - WARNING - Worker is at 68% memory usage. Resuming worker. Process memory: 2.65 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:43,659 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.13 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:43,980 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 3.20 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:44,200 - distributed.worker.memory - WARNING - Worker is at 78% memory usage. Resuming worker. Process memory: 3.04 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:44,294 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.11 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:44,656 - distributed.worker.memory - WARNING - Worker is at 85% memory usage. Pausing worker.  Process memory: 3.29 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:44,734 - distributed.worker.memory - WARNING - Worker is at 78% memory usage. Resuming worker. Process memory: 3.02 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:44,759 - distributed.worker.memory - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 3.06 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:44,944 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.14 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:45,166 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.10 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:45,476 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:45,534 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.32 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:45,597 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:45,787 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.65 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:46,234 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.10 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:46,314 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37769
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/utils.py", line 1910, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/comm/tcp.py", line 546, in connect
#     stream = await self.client.connect(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/tornado/tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/utils.py", line 1909, in wait_for
#     async with asyncio.timeout(timeout):
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/worker.py", line 2878, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/home/ubuntu/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/comm/core.py", line 368, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:37769 after 30 s
# 2025-01-29 22:02:47,124 - distributed.worker.memory - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 3.04 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,174 - distributed.worker.memory - WARNING - Worker is at 78% memory usage. Resuming worker. Process memory: 3.02 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,175 - distributed.worker.memory - WARNING - Worker is at 73% memory usage. Resuming worker. Process memory: 2.85 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,237 - distributed.worker.memory - WARNING - Worker is at 74% memory usage. Resuming worker. Process memory: 2.87 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,253 - distributed.worker.memory - WARNING - Worker is at 73% memory usage. Resuming worker. Process memory: 2.84 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,276 - distributed.worker.memory - WARNING - Worker is at 74% memory usage. Resuming worker. Process memory: 2.89 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,285 - distributed.worker.memory - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,288 - distributed.worker.memory - WARNING - Worker is at 78% memory usage. Resuming worker. Process memory: 3.01 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,307 - distributed.worker.memory - WARNING - Worker is at 76% memory usage. Resuming worker. Process memory: 2.94 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,342 - distributed.worker.memory - WARNING - Worker is at 71% memory usage. Resuming worker. Process memory: 2.76 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,365 - distributed.worker.memory - WARNING - Worker is at 74% memory usage. Resuming worker. Process memory: 2.86 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,385 - distributed.worker.memory - WARNING - Worker is at 73% memory usage. Resuming worker. Process memory: 2.83 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,403 - distributed.worker.memory - WARNING - Worker is at 74% memory usage. Resuming worker. Process memory: 2.87 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,471 - distributed.worker.memory - WARNING - Worker is at 74% memory usage. Resuming worker. Process memory: 2.89 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,567 - distributed.worker.memory - WARNING - Worker is at 78% memory usage. Resuming worker. Process memory: 3.03 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,615 - distributed.worker.memory - WARNING - Worker is at 72% memory usage. Resuming worker. Process memory: 2.80 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:47,827 - distributed.worker.memory - WARNING - Worker is at 66% memory usage. Resuming worker. Process memory: 2.55 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:48,142 - distributed.worker.memory - WARNING - Worker is at 77% memory usage. Resuming worker. Process memory: 2.99 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 22:02:48,213 - distributed.worker.memory - WARNING - Worker is at 72% memory usage. Resuming worker. Process memory: 2.79 GiB -- Worker memory limit: 3.85 GiB
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/scanpy/preprocessing/_highly_variable_genes.py:680, in highly_variable_genes(***failed resolving arguments***)
#     677 del min_disp, max_disp, min_mean, max_mean, n_top_genes
#     679 if batch_key is None:
# --> 680     df = _highly_variable_genes_single_batch(
#     681         adata, layer=layer, cutoff=cutoff, n_bins=n_bins, flavor=flavor
#     682     )
#     683 else:
#     684     df = _highly_variable_genes_batched(
#     685         adata, batch_key, layer=layer, cutoff=cutoff, n_bins=n_bins, flavor=flavor
#     686     )
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/scanpy/preprocessing/_highly_variable_genes.py:299, in _highly_variable_genes_single_batch(adata, layer, cutoff, n_bins, flavor)
#     296     else:
#     297         X = np.expm1(X)
# --> 299 mean, var = materialize_as_ndarray(_get_mean_var(X))
#     300 # now actually compute the dispersion
#     301 mean[mean == 0] = 1e-12  # set entries equal to zero to small value
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/scanpy/preprocessing/_distributed.py:49, in materialize_as_ndarray(a)
#      45     return tuple(np.asarray(arr) for arr in a)
#      47 import dask.array as da
# ---> 49 return da.compute(*a, sync=True)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/dask/base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/distributed/client.py:2427, in Client._gather(self, futures, errors, direct, local_worker)
#    2425     exception = st.exception
#    2426     traceback = st.traceback
# -> 2427     raise exception.with_traceback(traceback)
#    2428 if errors == "skip":
#    2429     bad_keys.add(key)
#
# KilledWorker: Attempted to run task ('sparse_chunk-a2afd6cab871adee92c5cfb8ba1a8129', 125, 0) on 4 different workers, but all those workers died while running it. The last worker that attempt to run the task was tcp://127.0.0.1:37453. Inspecting worker logs is often a good next step to diagnose what went wrong. For more information see https://distributed.dask.org/en/stable/killed.html.

# %% [markdown]
# ---
# Census `tissue_general` counts, for reference:
# ```python
# exp_obs = exp.obs.read().concat().to_pandas()
# exp_obs.tissue_general.value_counts()
# ```
# ```
# tissue_general
# brain                       26281059
# blood                       10835244
# lung                         6231233
# breast                       5555979
# eye                          4190842
# heart                        3629952
# kidney                       2083054
# liver                        1815408
# small intestine              1237182
# skin of body                 1045024
# endocrine gland               979667
# respiratory system            944355
# bone marrow                   813373
# spleen                        751041
# lymph node                    717899
# colon                         714413
# placenta                      638786
# reproductive system           570488
# adrenal gland                 560114
# nose                          470445
# adipose tissue                468603
# stomach                       446348
# prostate gland                348664
# fallopian tube                250178
# pancreas                      250161
# esophagus                     215951
# digestive system              211912
# musculature                   189452
# large intestine               180996
# pleural fluid                 179134
# yolk sac                      169725
# embryo                        165937
# uterus                        148198
# mucosa                        131978
# spinal cord                   117463
# exocrine gland                115722
# intestine                     104490
# immune system                  89046
# bladder organ                  82797
# vasculature                    63667
# ovary                          53751
# lamina propria                 45230
# tongue                         45060
# central nervous system         31780
# esophagogastric junction       29105
# axilla                         19792
# pleura                         19695
# skeletal system                14680
# saliva                         14502
# omentum                        14003
# testis                         13211
# tendon of semitendinosus       10533
# gallbladder                     9769
# scalp                           3029
# ureter                          2390
# Name: count, dtype: int64
# ```
