# %%
meas = "RNA"
layer = "raw"
census = "2024-07-01"
tissue = "tongue"
var_filter = None
dask_chunk_size = 0  # Non-Dask mode, by default
n_workers = None
threads_per_worker = 1
tdb_workers = None
dashboard_port = 8787

# %%
# Parameters
tissue = "colon"
dask_chunk_size = 2000
n_workers = 64
threads_per_worker = 1
tdb_workers = 1
dashboard_port = 8786

# %%
from concurrent.futures import ThreadPoolExecutor
from os import cpu_count
from typing import Literal
import anndata as ad
import scanpy as sc
from somacore import AxisQuery
from tiledbsoma import Experiment, SOMATileDBContext

DEFAULT_CONFIG = {
    "vfs.s3.no_sign_request": "true",
    "vfs.s3.region": "us-west-2"
}
CENSUS_S3 = "s3://cellxgene-census-public-us-west-2/cell-census"

species = "homo_sapiens"
soma_uri = f"{CENSUS_S3}/{census}/soma"
exp_uri = f"{soma_uri}/census_data/{species}"

if not tdb_workers:
    tdb_workers = cpu_count()

exp = Experiment.open(
    exp_uri,
    context=SOMATileDBContext(
        tiledb_config=DEFAULT_CONFIG,
        threadpool=ThreadPoolExecutor(max_workers=tdb_workers),
    ),
)
exp
# Out:
# <Experiment 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens' (open for 'r') (2 items)
#     'ms': 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens/ms' (unopened)
#     'obs': 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens/obs' (unopened)>

# %%
# %%time
obs_filter = f'tissue_general == "{tissue}"' if tissue else None
query = exp.axis_query(
    measurement_name=meas,
    obs_query=AxisQuery(value_filter=obs_filter) if obs_filter else None,
    var_query=AxisQuery(value_filter=var_filter) if var_filter else None,
)
# Out:
# CPU times: user 14.6 ms, sys: 1.15 ms, total: 15.8 ms
# Wall time: 178 ms

# %%
# %%time
query.n_obs
# Out:
# CPU times: user 614 ms, sys: 952 ms, total: 1.57 s
# Wall time: 535 ms
# 714413

# %%
from dask.distributed import Client, LocalCluster
if dask_chunk_size:
    if n_workers is None:
        n_workers = cpu_count() // tdb_workers // threads_per_worker
    cluster = LocalCluster(
        n_workers=n_workers,
        threads_per_worker=threads_per_worker,
        dashboard_address=f":{dashboard_port}",
    )
    print(f"{n_workers=}, {threads_per_worker=}, {tdb_workers=}")
    client = Client(cluster)
else:
    dask_chunk_size = None
    client = None
client
# Out:
# n_workers=64, threads_per_worker=1, tdb_workers=1
# <Client: 'tcp://127.0.0.1:42289' processes=64 threads=64, memory=246.55 GiB>

# %% [markdown]
# ## HVG

# %%
# %%time
add = query.to_anndata(layer, dask_chunk_size=dask_chunk_size)
add
# Out:
# CPU times: user 3.07 s, sys: 2.97 s, total: 6.04 s
# Wall time: 1.92 s
# AnnData object with n_obs × n_vars = 714413 × 60530
#     obs: 'soma_joinid', 'dataset_id', 'assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'observation_joinid', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'suspension_type', 'tissue', 'tissue_ontology_term_id', 'tissue_type', 'tissue_general', 'tissue_general_ontology_term_id', 'raw_sum', 'nnz', 'raw_mean_nnz', 'raw_variance_nnz', 'n_measured_vars'
#     var: 'soma_joinid', 'feature_id', 'feature_name', 'feature_length', 'nnz', 'n_measured_obs'

# %%
# %%time
sc.pp.normalize_total(add)
# Out:
# CPU times: user 110 ms, sys: 28.1 ms, total: 138 ms
# Wall time: 133 ms

# %%
# %%time
sc.pp.log1p(add)
# Out:
# CPU times: user 3.05 ms, sys: 4 μs, total: 3.05 ms
# Wall time: 3.08 ms

# %%
# %%time
hvg = sc.pp.highly_variable_genes(add, inplace=False, subset=True)
hvg
# Out:
# 2025-01-29 21:43:17,353 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.68 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:22,463 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.66 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:25,825 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.54 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:27,535 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.69 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:27,691 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.69 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:27,721 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.71 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:31,262 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.68 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:32,178 - distributed.worker.memory - WARNING - gc.collect() took 3.296s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:43:32,188 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.13 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:32,226 - distributed.worker.memory - WARNING - gc.collect() took 3.395s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:43:32,227 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.09 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:32,312 - distributed.worker.memory - WARNING - Worker is at 29% memory usage. Resuming worker. Process memory: 1.15 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:32,326 - distributed.worker.memory - WARNING - Worker is at 29% memory usage. Resuming worker. Process memory: 1.13 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:32,689 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.72 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:34,452 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.53 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:35,085 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.82 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:35,299 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.62 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:35,534 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.63 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:36,871 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.50 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:37,585 - distributed.worker.memory - WARNING - gc.collect() took 3.676s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:43:37,586 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.08 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:37,626 - distributed.worker.memory - WARNING - Worker is at 29% memory usage. Resuming worker. Process memory: 1.13 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:38,139 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.80 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:38,651 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.58 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:38,865 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.57 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:41,538 - distributed.worker.memory - WARNING - gc.collect() took 2.597s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:43:41,539 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.11 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:41,560 - distributed.worker.memory - WARNING - Worker is at 34% memory usage. Resuming worker. Process memory: 1.32 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:41,951 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.84 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:42,199 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.71 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:42,415 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.75 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:42,421 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.83 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:43,304 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.61 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:44,107 - distributed.worker.memory - WARNING - gc.collect() took 1.172s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:43:44,108 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.12 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:44,218 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.81 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:44,268 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 2.15 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:44,496 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.72 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:44,890 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.53 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:45,151 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.50 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:45,196 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.61 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:45,931 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.68 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:46,840 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.68 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:47,097 - distributed.worker.memory - WARNING - gc.collect() took 3.742s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:43:47,098 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.12 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:47,167 - distributed.worker.memory - WARNING - Worker is at 31% memory usage. Resuming worker. Process memory: 1.20 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:47,435 - distributed.worker.memory - WARNING - gc.collect() took 3.660s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:43:47,444 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.09 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:47,544 - distributed.worker.memory - WARNING - Worker is at 32% memory usage. Resuming worker. Process memory: 1.25 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:48,294 - distributed.worker.memory - WARNING - gc.collect() took 1.719s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:43:48,295 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.15 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:48,413 - distributed.worker.memory - WARNING - Worker is at 39% memory usage. Resuming worker. Process memory: 1.50 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:49,249 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.57 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:49,337 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.61 GiB -- Worker memory limit: 3.85 GiB
# 2025-01-29 21:43:49,884 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.57 GiB -- Worker memory limit: 3.85 GiB
# CPU times: user 58.1 s, sys: 13.4 s, total: 1min 11s
# Wall time: 1min 18s
#           means  dispersions           mean_bin  dispersions_norm  \
# 1      0.026894     1.289713  (-0.00486, 0.243]          0.810094
# 5      0.014958     1.619181  (-0.00486, 0.243]          1.197983
# 6      0.131333     2.046089  (-0.00486, 0.243]          1.700591
# 8      0.064922     1.228058  (-0.00486, 0.243]          0.737507
# 13     0.026449     1.090968  (-0.00486, 0.243]          0.576108
# ...         ...          ...                ...               ...
# 51229  0.018870     1.307655  (-0.00486, 0.243]          0.831218
# 51526  0.027907     1.786350  (-0.00486, 0.243]          1.394795
# 53899  0.022165     1.578129  (-0.00486, 0.243]          1.149652
# 56651  0.020105     1.251600  (-0.00486, 0.243]          0.765223
# 57029  0.014639     2.235196  (-0.00486, 0.243]          1.923231
#
#        highly_variable
# 1                 True
# 5                 True
# 6                 True
# 8                 True
# 13                True
# ...                ...
# 51229             True
# 51526             True
# 53899             True
# 56651             True
# 57029             True
#
# [3187 rows x 5 columns]

# %% [markdown]
# ---
# Census `tissue_general` counts, for reference:
# ```python
# exp_obs = exp.obs.read().concat().to_pandas()
# exp_obs.tissue_general.value_counts()
# ```
# ```
# tissue_general
# brain                       26281059
# blood                       10835244
# lung                         6231233
# breast                       5555979
# eye                          4190842
# heart                        3629952
# kidney                       2083054
# liver                        1815408
# small intestine              1237182
# skin of body                 1045024
# endocrine gland               979667
# respiratory system            944355
# bone marrow                   813373
# spleen                        751041
# lymph node                    717899
# colon                         714413
# placenta                      638786
# reproductive system           570488
# adrenal gland                 560114
# nose                          470445
# adipose tissue                468603
# stomach                       446348
# prostate gland                348664
# fallopian tube                250178
# pancreas                      250161
# esophagus                     215951
# digestive system              211912
# musculature                   189452
# large intestine               180996
# pleural fluid                 179134
# yolk sac                      169725
# embryo                        165937
# uterus                        148198
# mucosa                        131978
# spinal cord                   117463
# exocrine gland                115722
# intestine                     104490
# immune system                  89046
# bladder organ                  82797
# vasculature                    63667
# ovary                          53751
# lamina propria                 45230
# tongue                         45060
# central nervous system         31780
# esophagogastric junction       29105
# axilla                         19792
# pleura                         19695
# skeletal system                14680
# saliva                         14502
# omentum                        14003
# testis                         13211
# tendon of semitendinosus       10533
# gallbladder                     9769
# scalp                           3029
# ureter                          2390
# Name: count, dtype: int64
# ```
