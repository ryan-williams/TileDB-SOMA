# %%
meas = "RNA"
layer = "raw"
census = "2024-07-01"
tissue = "tongue"
var_filter = None
dask_chunk_size = 0  # Non-Dask mode, by default
n_workers = None
threads_per_worker = 1
tdb_workers = 4
dashboard_port = 8787

# %%
# Parameters
tissue = "placenta"
dask_chunk_size = 2000
n_workers = 16
threads_per_worker = 4
tdb_workers = 1
dashboard_port = 8786

# %%
from concurrent.futures import ThreadPoolExecutor
from os import cpu_count
from typing import Literal
import anndata as ad
import scanpy as sc
from somacore import AxisQuery
from tiledbsoma import Experiment, SOMATileDBContext

DEFAULT_CONFIG = {
    "vfs.s3.no_sign_request": "true",
    "vfs.s3.region": "us-west-2"
}
CENSUS_S3 = "s3://cellxgene-census-public-us-west-2/cell-census"

species = "homo_sapiens"
soma_uri = f"{CENSUS_S3}/{census}/soma"
exp_uri = f"{soma_uri}/census_data/{species}"

exp = Experiment.open(
    exp_uri,
    context=SOMATileDBContext(
        tiledb_config=DEFAULT_CONFIG,
        threadpool=ThreadPoolExecutor(max_workers=tdb_workers),
    ),
)
exp
# Out:
# <Experiment 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens' (open for 'r') (2 items)
#     'ms': 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens/ms' (unopened)
#     'obs': 's3://cellxgene-census-public-us-west-2/cell-census/2024-07-01/soma/census_data/homo_sapiens/obs' (unopened)>

# %%
# %%time
obs_filter = f'tissue_general == "{tissue}"' if tissue else None
query = exp.axis_query(
    measurement_name=meas,
    obs_query=AxisQuery(value_filter=obs_filter) if obs_filter else None,
    var_query=AxisQuery(value_filter=var_filter) if var_filter else None,
)
# Out:
# CPU times: user 10.7 ms, sys: 3.95 ms, total: 14.7 ms
# Wall time: 165 ms

# %%
# %%time
query.n_obs
# Out:
# CPU times: user 625 ms, sys: 1.3 s, total: 1.92 s
# Wall time: 635 ms
# 638786

# %%
from dask.distributed import Client, LocalCluster
if dask_chunk_size:
    if n_workers is None:
        n_workers = cpu_count() // tdb_workers // threads_per_worker
    cluster = LocalCluster(
        n_workers=n_workers,
        threads_per_worker=threads_per_worker,
        dashboard_address=f":{dashboard_port}",
    )
    print(f"{n_workers=}, {threads_per_worker=}, {tdb_workers=}")
    client = Client(cluster)
else:
    dask_chunk_size = None
    client = None
client
# Out:
# n_workers=16, threads_per_worker=4, tdb_workers=1
# <Client: 'tcp://127.0.0.1:46345' processes=16 threads=64, memory=246.55 GiB>

# %% [markdown]
# ## HVG

# %%
# %%time
add = query.to_anndata(layer, dask_chunk_size=dask_chunk_size)
add
# Out:
# CPU times: user 1.94 s, sys: 2.17 s, total: 4.12 s
# Wall time: 1.93 s
# AnnData object with n_obs × n_vars = 638786 × 60530
#     obs: 'soma_joinid', 'dataset_id', 'assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'observation_joinid', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'suspension_type', 'tissue', 'tissue_ontology_term_id', 'tissue_type', 'tissue_general', 'tissue_general_ontology_term_id', 'raw_sum', 'nnz', 'raw_mean_nnz', 'raw_variance_nnz', 'n_measured_vars'
#     var: 'soma_joinid', 'feature_id', 'feature_name', 'feature_length', 'nnz', 'n_measured_obs'

# %%
# %%time
sc.pp.normalize_total(add)
# Out:
# CPU times: user 99.3 ms, sys: 25.9 ms, total: 125 ms
# Wall time: 119 ms

# %%
# %%time
sc.pp.log1p(add)
# Out:
# CPU times: user 2.58 ms, sys: 0 ns, total: 2.58 ms
# Wall time: 2.6 ms

# %%
# %%time
hvg = sc.pp.highly_variable_genes(add, inplace=False, subset=True)
hvg
# Out:
# 2025-01-29 21:14:22,670 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.37 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:23,166 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.92 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:24,896 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.02 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:28,471 - distributed.worker.memory - WARNING - gc.collect() took 8.620s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:14:28,472 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 12.44 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:28,498 - distributed.worker.memory - WARNING - Worker is at 24% memory usage. Resuming worker. Process memory: 3.76 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:29,621 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.41 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:30,035 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.03 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:30,128 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.24 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:35,375 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.48 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:36,132 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 9.37 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:42,258 - distributed.worker.memory - WARNING - gc.collect() took 9.504s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-01-29 21:14:42,259 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 12.54 GiB -- Worker memory limit: 15.41 GiB
# 2025-01-29 21:14:42,946 - distributed.worker.memory - WARNING - Worker is at 22% memory usage. Resuming worker. Process memory: 3.52 GiB -- Worker memory limit: 15.41 GiB
# CPU times: user 51.1 s, sys: 9.04 s, total: 1min
# Wall time: 2min 1s
#           means  dispersions          mean_bin  dispersions_norm  \
# 14     0.092254     2.359177  (-0.00561, 0.28]          0.865045
# 15     0.018185     2.020049  (-0.00561, 0.28]          0.553303
# 24     0.428312     4.409582     (0.28, 0.561]          4.928617
# 26     0.028136     2.201727  (-0.00561, 0.28]          0.720310
# 33     0.013141     2.132764  (-0.00561, 0.28]          0.656916
# ...         ...          ...               ...               ...
# 57029  0.016431     2.532290  (-0.00561, 0.28]          1.024178
# 57873  0.032180     2.455130  (-0.00561, 0.28]          0.953249
# 59217  0.063744     2.072049  (-0.00561, 0.28]          0.601104
# 59353  0.013538     2.208245  (-0.00561, 0.28]          0.726302
# 59611  0.029507     2.006180  (-0.00561, 0.28]          0.540555
#
#        highly_variable
# 14                True
# 15                True
# 24                True
# 26                True
# 33                True
# ...                ...
# 57029             True
# 57873             True
# 59217             True
# 59353             True
# 59611             True
#
# [2919 rows x 5 columns]

# %% [markdown]
# ---
# Census `tissue_general` counts, for reference:
# ```python
# exp_obs = exp.obs.read().concat().to_pandas()
# exp_obs.tissue_general.value_counts()
# ```
# ```
# tissue_general
# brain                       26281059
# blood                       10835244
# lung                         6231233
# breast                       5555979
# eye                          4190842
# heart                        3629952
# kidney                       2083054
# liver                        1815408
# small intestine              1237182
# skin of body                 1045024
# endocrine gland               979667
# respiratory system            944355
# bone marrow                   813373
# spleen                        751041
# lymph node                    717899
# colon                         714413
# placenta                      638786
# reproductive system           570488
# adrenal gland                 560114
# nose                          470445
# adipose tissue                468603
# stomach                       446348
# prostate gland                348664
# fallopian tube                250178
# pancreas                      250161
# esophagus                     215951
# digestive system              211912
# musculature                   189452
# large intestine               180996
# pleural fluid                 179134
# yolk sac                      169725
# embryo                        165937
# uterus                        148198
# mucosa                        131978
# spinal cord                   117463
# exocrine gland                115722
# intestine                     104490
# immune system                  89046
# bladder organ                  82797
# vasculature                    63667
# ovary                          53751
# lamina propria                 45230
# tongue                         45060
# central nervous system         31780
# esophagogastric junction       29105
# axilla                         19792
# pleura                         19695
# skeletal system                14680
# saliva                         14502
# omentum                        14003
# testis                         13211
# tendon of semitendinosus       10533
# gallbladder                     9769
# scalp                           3029
# ureter                          2390
# Name: count, dtype: int64
# ```
